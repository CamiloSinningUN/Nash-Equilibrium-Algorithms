# %% [markdown]
# # Modified Dresher Procedure
#
#
# (i) Set t := 0, and let $Φ^0_2$ := $Φ_2$.
#
# (ii) Find an optimal solution to $P_t$.
#
# (iii) Find an optimal solution to $Q_t$. Let $Φ^{t+1}_2$ be those $k \in \phi_2^t$ where $p_k$ =1 in the optimal solution found.
#
# (iv) If $Φ^{t+1}_2 = ∅$ then go to (v) else replace t by t+1 and go to (ii).
#
# (v) The set of D-optimal strategies of Player 1 in Γ is the set of optimal solutions to $P_t$. Output any one of these optimal solutions.

# %%
from amplpy import AMPL
import pandas as pd
import numpy as np
import sys

# %% [markdown]
# ## Test (Parsimonious penny matching)

# %%
def P_0(A_T, I):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        
        # Params
        param A_T {I_2, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        
        # Constraints
        subject to c2{i in I_2}: sum{j in I_1} A_T[i, j] * x[j] >= z;
        subject to c3: sum{j in I_1} x[j] = 1;
        
        # Objective
        maximize obj: z;
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    
    ampl.param['A_T'] = A_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    z = ampl.getObjective('obj').value()
    
    # close AMPL
    ampl.close()
    
    return z,x

# %%
def Q_0(A_pp_T, I):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        
        # Params
        param t;
        param A_pp_T {I_2, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        var p{I_2} >= 0, <= 1;
        
        # Constraints
        subject to c2{i in I_2}: sum{j in I_1} A_pp_T[i, j] * x[j] >= p[i];
        
        # Objective
        maximize obj: sum{i in I_2} p[i];
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    
    ampl.param['A_pp_T'] = A_pp_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    p = ampl.getVariable('p').getValues().toPandas()
    
    # close AMPL
    ampl.close()
    
    return p,x

# %%
def P_1(A_T, A_p_T, I, I_2_p):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        set I_2_p;
        
        # Params
        param A_T {I_2, I_1};
        param A_p_T {I_2_p, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        
        # Constraints
        subject to c1{i in I_2_p}: sum{j in I_1} A_p_T[i, j] * x[j] >= 0;
        subject to c2{i in I_2}: sum{j in I_1} A_T[i, j] * x[j] >= z;
        subject to c3: sum{j in I_1} x[j] = 1;
        
        # Objective
        maximize obj: z;
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    ampl.set['I_2_p'] = I_2_p
    
    ampl.param['A_T'] = A_T
    ampl.param['A_p_T'] = A_p_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    z = ampl.getObjective('obj').value()
    
    # close AMPL
    ampl.close()
    
    return z,x

# %%
def Q_1(A_p_T, A_pp_T, I, I_2_p):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        set I_2_p;
        
        # Params
        param t;
        param A_pp_T {I_2, I_1};
        param A_p_T {I_2_p, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        var p{I_2} >= 0, <= 1;
        
        # Constraints
        subject to c1{i in I_2_p}: sum{j in I_1} A_p_T[i, j] * x[j] >= 0;
        subject to c2{i in I_2}: sum{j in I_1} A_pp_T[i, j] * x[j] >= p[i];
        
        # Objective
        maximize obj: sum{i in I_2} p[i];
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    ampl.set['I_2_p'] = I_2_p
    
    ampl.param['A_pp_T'] = A_pp_T
    ampl.param['A_p_T'] = A_p_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    p = ampl.getVariable('p').getValues().toPandas()
    
    # close AMPL
    ampl.close()
    
    return p,x

# %%
# Game
Players = [1, 2]

A_1 = ["guess_heads_up", "guess_tails_up"]
A_2 = ["hide penny heads up", "hide penny tails up", "tease"]
I = {1: A_1, 2: A_2}

U1 = [[1,0,0], 
    [0,1,0]]

U2 = [[0,1,1], 
    [1,0,1]]

U = {1: U1, 2: U2}

# %%
# Algorithm
# --------Iteration 0--------
t = 0;

U_df = {player: pd.DataFrame(U[player], index=I[1], columns=I[2]) for player in Players}
A_T = U_df[1].transpose()

z, x = P_0(A_T, I)

A_pp_T = A_T - z

p, x = Q_0(A_pp_T, I)

# Put in A_prime the actions that are not superflous, the 
A_p_T = A_T.loc[p.iloc[:,0] == 0] 

print(A_p_T)  

# Leave only superflous actions
A_T = A_T.loc[p.iloc[:,0] != 0]
print(A_T)
# I[2] = [I[2][i] for i in range(len(I[2])) if p.iloc[i,0] != 0]

# --------Iteration 1--------
t = 1

I_2_p = [I[2][i] for i in range(len(I[2])) if p.iloc[i,0] == 0]
I[2] = [I[2][i] for i in range(len(I[2])) if p.iloc[i,0] != 0]

z, x = P_1(A_T, A_p_T, I, I_2_p)

print(f"\nResults P_{1}:")
print("z:", z)
print("x:\n",x.iloc[:,0])

A_pp_T = A_T - z

p, x = Q_1(A_p_T, A_pp_T, I, I_2_p)

print(f"\nResults Q_{1}:")
print("p:", p)
print("x:\n",x.iloc[:,0])


while True:
    break
    T = range(t)
    
    z, x = P(T, A_T, A_prime_T, I)

    print(f"\nResults P_{t}:")
    print("z:", z)
    print("x:\n",x.iloc[:,0])
    
    p, x = Q_0(A_T, I)
    
    print(f"\nResults Q_{t}:")
    print("p:", p)
    print("x:\n",x.iloc[:,0])
    
    t+=1
    break
    # Break condition
    if all(p.iloc[:,0] == 0):
        break
# Out:
# Gurobi 9.5.1: optimal solution; objective 0
# Gurobi 9.5.1: optimal solution; objective 2
#        guess_heads_up  guess_tails_up
# tease               0               0
#                      guess_heads_up  guess_tails_up
# hide penny heads up               1               0
# hide penny tails up               0               1
# Gurobi 9.5.1: optimal solution; objective 0.5
# 1 simplex iterations
# Results P_1:
# z: 0.5
# x:
#  guess_heads_up    0.5
# guess_tails_up    0.5
# Name: x.val, dtype: float64
# Gurobi 9.5.1: optimal solution; objective 0
#
# Results Q_1:
# p:                      p.val
# hide penny heads up      0
# hide penny tails up      0
# x:
#  guess_heads_up    0
# guess_tails_up    0
# Name: x.val, dtype: int64

# %% [markdown]
# # General function with procedure

# %%
def P_legacy(T, A_T, A_prime_T, I):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        set T;
        
        # Params
        param A_T {I_2, I_1};
        param A_prime_T {T, I_2, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        
        # Constraints
        
        subject to c1{t in T, i in I_2}: sum{j in I_1} A_prime_T[t,i,j] * x[j] >= 0;
        
        subject to c2{i in I_2}: sum{j in I_1} A_T[i, j] * x[j] >= z;
        
        subject to c3: sum{j in I_1} x[j] = 1;
        
        # Objective
        
        maximize obj: z;
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    ampl.set['T'] = T
    
    ampl.param['A_T'] = A_T
    ampl.param['A_prime_T'] = A_prime_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    z = ampl.getObjective('obj').value()
    
    # close AMPL
    ampl.close()
    
    return z,x

# %%
def P(T, A_T, A_p_T, I, I_2_p):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        set I_2_p;
        set T;
        
        # Params
        param A_T {I_2, I_1};
        param A_p_T {T, I_2_p, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        
        # Constraints
        subject to c1{t in T, i in I_2_p}: sum{j in I_1} A_p_T[t, i, j] * x[j] >= 0;
        subject to c2{i in I_2}: sum{j in I_1} A_T[i, j] * x[j] >= z;
        subject to c3: sum{j in I_1} x[j] = 1;
        
        # Objective
        maximize obj: z;
    """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    ampl.set['I_2_p'] = I_2_p
    ampl.set['T'] = T
    
    ampl.param['A_T'] = A_T
    ampl.param['A_p_T'] = A_p_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    z = ampl.getObjective('obj').value()
    
    ampl.close()
    
    return z,x

# %%
def Q(T, A_p_T, A_pp_T, I, I_2_p):
    ampl = AMPL()
    
    ampl.eval(r"""
        # Sets
        set I_1;
        set I_2;
        set I_2_p;
        set T;
        
        # Params
        param A_p_T {T, I_2_p, I_1};
        param A_pp_T {I_2, I_1};
        
        # Vars
        var z;
        var x{I_1} >= 0;
        var p{I_2} >= 0, <= 1;
        
        # Constraints
        subject to c1{t in T, i in I_2_p}: sum {j in I_1} A_p_T[t, i, j] * x[j] >= 0;
        subject to c2{i in I_2}: sum{j in I_1} A_pp_T[i, j] * x[j] >= p[i];
        
        # Objective
        maximize obj: sum{i in I_2} p[i];
        """)
    
    ampl.set['I_1'] = I[1]
    ampl.set['I_2'] = I[2]
    ampl.set['I_2_p'] = I_2_p
    ampl.set['T'] = T
    
    ampl.param['A_pp_T'] = A_pp_T
    ampl.param['A_p_T'] = A_p_T

    # AMPL solver
    ampl.solve(solver='gurobi')
    assert ampl.solve_result == "solved"
    
    x = ampl.getVariable('x').getValues().toPandas()
    p = ampl.getVariable('p').getValues().toPandas()
    
    # close AMPL
    ampl.close()
    
    return p,x

# %%
def modified_dresher_procedure(U_df, I):
    t = 0
    A_p_T_list = []
    A_p_T = []
    I_2_p = []
    A_T = U_df[1].transpose()
    
    while True:
        print(f"\nIteration {t}:")
        T = range(t)  
        
        z, x = P(T, A_T, A_p_T, I, I_2_p)
        
        print(f"\nResults P_{t}:")
        print("z:", z)
        print("x:\n",x.iloc[:,0])
        
        A_pp_T = A_T - z
        
        p, x = Q(T, A_p_T, A_pp_T, I, I_2_p)
        
        print(f"\nResults Q_{t}:")
        print("p:", p)
        print("x:\n",x.iloc[:,0])
        
        t+=1
        
        A_p_T_list.append(A_T.loc[p.iloc[:,0] == 0])
        A_p_T = pd.concat(A_p_T_list, keys=range(t))    
        A_T = A_T.loc[p.iloc[:,0] != 0]
        
        I_2_p = [I[2][i] for i in range(len(I[2])) if p.iloc[i,0] == 0]
        I[2] = [I[2][i] for i in range(len(I[2])) if p.iloc[i,0] != 0]
        
        # Stop condition
        if all(p.iloc[:,0] == 0):
            break
    return x.iloc[:,0]

# %%
def find_proper_equilibrium(players, actions, utility_matrices):
    U_df = {player: pd.DataFrame(utility_matrices[player], index=I[1], columns=I[2]) for player in Players}
    return {p: modified_dresher_procedure(U_df, I = actions) for p in players}

# %%
# Game
Players = [1, 2]

A_1 = ["guess_heads_up", "guess_tails_up"]
A_2 = ["hide penny heads up", "hide penny tails up", "tease"]
I = {1: A_1, 2: A_2}

U1 = [[1,0,0], 
    [0,1,0]]

U2 = [[0,1,1], 
    [1,0,1]]

U = {1: U1, 2: U2}

sigmas = find_proper_equilibrium(Players, I, U)

print("\nResults:")
for p in Players:
    print(f"Player {p} strategy is:")
    print(sigmas[p])
# Out:
# Iteration 0:
# Gurobi 9.5.1: optimal solution; objective 0
# Results P_0:
# z: 0.0
# x:
#  guess_heads_up    1
# guess_tails_up    0
# Name: x.val, dtype: int64
# Gurobi 9.5.1: optimal solution; objective 2
#
# Results Q_0:
# p:                      p.val
# hide penny heads up      1
# hide penny tails up      1
# tease                    0
# x:
#  guess_heads_up    1
# guess_tails_up    1
# Name: x.val, dtype: int64
#
# Iteration 1:
# Gurobi 9.5.1: optimal solution; objective 0.5
# 1 simplex iterations
#
# Results P_1:
# z: 0.5
# x:
#  guess_heads_up    0.5
# guess_tails_up    0.5
# Name: x.val, dtype: float64
# Gurobi 9.5.1: optimal solution; objective 0
#
# Results Q_1:
# p:                      p.val
# hide penny heads up      0
# hide penny tails up      0
# x:
#  guess_heads_up    0
# guess_tails_up    0
# Name: x.val, dtype: int64
#
# Iteration 0:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[440], line 16
#      11 U2 = [[0,1,1],
#      12     [1,0,1]]
#      14 U = {1: U1, 2: U2}
# ---> 16 sigmas = find_proper_equilibrium(Players, I, U)
#      18 print("\nResults:")
#      19 for p in Players:
#
# Cell In[439], line 3, in find_proper_equilibrium(players, actions, utility_matrices)
#       1 def find_proper_equilibrium(players, actions, utility_matrices):
#       2     U_df = {player: pd.DataFrame(utility_matrices[player], index=I[1], columns=I[2]) for player in Players}
# ----> 3     return {p: modified_dresher_procedure(U_df, I = actions) for p in players}
#
# Cell In[439], line 3, in <dictcomp>(.0)
#       1 def find_proper_equilibrium(players, actions, utility_matrices):
#       2     U_df = {player: pd.DataFrame(utility_matrices[player], index=I[1], columns=I[2]) for player in Players}
# ----> 3     return {p: modified_dresher_procedure(U_df, I = actions) for p in players}
#
# Cell In[438], line 12, in modified_dresher_procedure(U_df, I)
#       9 print(f"\nIteration {t}:")
#      10 T = range(t)
# ---> 12 z, x = P(T, A_T, A_p_T, I, I_2_p)
#      14 print(f"\nResults P_{t}:")
#      15 print("z:", z)
#
# Cell In[436], line 33, in P(T, A_T, A_p_T, I, I_2_p)
#      30 ampl.set['I_2_p'] = I_2_p
#      31 ampl.set['T'] = T
# ---> 33 ampl.param['A_T'] = A_T
#      34 ampl.param['A_p_T'] = A_p_T
#      36 # AMPL solver
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\amplpy\ampl.py:753, in AMPL._param.<locals>.Parameters.__setitem__(self, name, value)
#     751     self.ampl.get_parameter(name).set(value)
#     752 else:
# --> 753     self.ampl.get_parameter(name).set_values(value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\amplpy\parameter.py:126, in Parameter.set_values(self, values)
#     124     Entity.set_values(self, values)
#     125 elif pd is not None and isinstance(values, (pd.DataFrame, pd.Series)):
# --> 126     Entity.set_values(self, values)
#     127 elif np is not None and isinstance(values, np.ndarray):
#     128     if len(values.shape) <= 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\amplpy\entity.py:230, in Entity.set_values(self, data)
#     228 if pd is not None and isinstance(data, (pd.DataFrame, pd.Series)):
#     229     df = DataFrame.from_pandas(data, indexarity=self.indexarity())
# --> 230     self._impl.setValuesDf(df._impl)
#     231     return
#     232 raise TypeError(f"Unexpected data type: {type(data)}.")
#
# RuntimeError: Error executing "let" command:
# 	invalid subscript A_T['hide penny heads up','guess_heads_up']
